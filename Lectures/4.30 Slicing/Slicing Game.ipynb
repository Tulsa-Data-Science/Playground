# %% [markdown]
# ## Slicing
#
# **By:** Mijael Martinez
#
# *Dataset Credits:*
# * [Josh Kaufman's 10000 most common words in English](https://github.com/first20hours/google-10000-english)
# * [Webster's Learners Dictionary](http://learnersdictionary.com/3000-words)
#
# *Puzzle adapted from the work of:* [Richard Boulton's Word Generator](https://github.com/rboulton/wordsearch)

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from wordsearch import make_grid as mg

# %%
#%matplotlib inline
# %matplotlib notebook
# %pylab inline
#np.random.seed(5)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
d = pd.read_excel("./Dictionary.xlsx", sheetname="Sheet2")

# %%
d.head()
# Out:
#             Category                Category Description     Word.1 Word.2
# 0  Sports vocabulary   Words for popular American sports    amateur    NaN
# 1  Sports vocabulary   Words for popular American sports      arena    NaN
# 2  Sports vocabulary   Words for popular American sports   athletic    NaN
# 3  Sports vocabulary   Words for popular American sports  backboard    NaN
# 4  Sports vocabulary   Words for popular American sports   backhand    NaN

# %%
wcats = d["Category"].unique()
curcat = numpy.random.choice(wcats)
words = d[d["Category"] == curcat]
w = words.head(10)["Word.1"].values

# %%
#grid = mg(words=["one", "circle", "Hermionie", "Big Brother", "privacy"])
grid = mg(words=w)
puzzle = grid.to_text().upper().split("\n")
puzzle = [list(puzzle[i]) for i in range(len(puzzle))]
p = np.array(puzzle)

# %%
plt.xkcd()
fig = plt.figure(figsize=(6, 6))
ax = fig.add_subplot(111)
ax.axis('equal')

ax.set_xlim(-1, 15)
ax.set_ylim(-1, 15)
ax.set_ylim(ax.get_ylim()[::-1])
xticks(np.arange(0, 15, step=1))
yticks(np.arange(0, 15, step=1))
ax.grid(True, axis="both")

plt.title(curcat)
for i in range(15):
    for j in range(15):
        ax.text(i, j, (puzzle[j][i]),size=14)

for i, w in enumerate(w):
    ax.text(20, i, (w),size=14)

# %% [markdown]
# ### Let's play!

# %%
p[4,9:1:-1]
# Out:
# array(['E', 'H', 'T', 'O', 'R', 'B', 'J', 'S'], dtype='<U1')

# %%
"".join(p[13-i,3+i] for i in range(0,8))
# Out:
# 'DAUGHTER'

# %%
"".join(p[13,7:13])
# Out:
# 'SISTER'

# %%
"".join(p[8-i,4+i] for i in range(0,3))
# Out:
# 'DAD'

# %%
"".join(p[9-i,0+i] for i in range(0,8))
# Out:
# 'CHILDREN'

# %%
"".join(p[3,7:13])
# Out:
# 'PARENT'

# %%
"".join(p[2, 9:15].tolist())
# Out:
# 'FATHER'

# %%
"".join(p[4, 4:11].tolist())
# Out:
# 'BROTHER'

# %%
"".join(p[5:8,11].tolist())
# Out:
# 'MOM'

# %%
"".join([p[13-i,5+i] for i in range(0,6)])
# Out:
# 'MOTHER'

# %%
"".join(p[2:8,0].tolist())

# %%
"".join(p[8:11,8].tolist())

# %%
"".join(p[10,12:4:-1].tolist())

# %%
"".join(p[0,12:4:-1].tolist())

# %%
"".join(p[10:13,4].tolist())

# %%
"".join(p[6,11:4:-1].tolist())

# %%
"".join(p[1,8:2:-1].tolist())

# %% [markdown]
# *Cheat:* `print(grid.used_to_text())`
